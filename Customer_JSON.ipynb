# %% [markdown]
# <a href="https://colab.research.google.com/github/VAISH-16/INVENTORY-MANAGEMENT-SYSTEM/blob/main/Customer_JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %%
record = { 556671: {'Product name' : 'Dairy Milk', 'Brand Name' : 'Cadbury', 'Opening Quantity' : 100 , 'Closing Quantity' : 100, 'Sale Price' : 100, 'Purchase Price': 80 },
           556672: {'Product name' : 'Kitkat','Brand Name' : 'Nestle global', 'Opening Quantity': 100 , 'Closing Quantity':100   ,'Sale Price': 40, 'Purchase Price': 20},
            556673: {'Product name' : 'Five star', 'Brand Name' :'Cadbury', 'Opening Quantity':100 , 'Closing Quantity':100    ,'Sale Price': 10, 'Purchase Price': 5},
            556674: {'Product name' :'Eclairs', 'Brand Name' : 'Cadbury', 'Opening Quantity':100, 'Closing Quantity':100    ,'Sale Price': 2, 'Purchase Price': 1},
            556675: {'Product name' : 'Dark Fantasy', 'Brand Name' : 'SunFeast', 'Opening Quantity':100 , 'Closing Quantity':100   ,'Sale Price': 50, 'Purchase Price':40},
            556676: {'Product name' : 'Perk', 'Brand Name' :'Cadbury', 'Opening Quantity':100 , 'Closing Quantity':100   ,'Sale Price': 20, 'Purchase Price':15},
            556677: {'Product name' :'Bournville', 'Brand Name': 'Cadbury', 'Opening Quantity':100,  'Closing Quantity':100   ,'Sale Price': 100 , 'Purchase Price':75},
            556678: {'Product name' :'Dark Chocolate','Brand Name' :'Amul', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 100, 'Purchase Price':80},
            556679:{'Product name' :'Munch','Brand Name' :'Nestle', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 10, 'Purchase Price': 8} ,
            556680:{'Product name' :'Milkybar','Brand Name' :'Nestle', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 10, 'Purchase Price':8},
            556681:{'Product name' :'Melody','Brand Name' :'Parle', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 50, 'Purchase Price':40},
            556682:{'Product name' :'Bounty','Brand Name' :'Procter & Gamble', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 100, 'Purchase Price':80},
            556683:{'Product name' :'Ferrero Rocher','Brand Name' :'Ferrero Rocher', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 100, 'Purchase Price':80},
            556684:{'Product name' :'Toblerone','Brand Name' :'Cadbury', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 100, 'Purchase Price':80},
            556685:{'Product name' :'Mars','Brand Name' :'Mars', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 50, 'Purchase Price':40},
            556686:{'Product name' :'Gems','Brand Name' :'Cadbury', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 10, 'Purchase Price':8},
            556687:{'Product name' :'Temptation','Brand Name' :'Cadbury', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 100, 'Purchase Price':80},
            556688:{'Product name' :'Safari','Brand Name' :'Gandour', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 80, 'Purchase Price':70},
            556689:{'Product name' :'Galaxy','Brand Name' :'Mars', 'Opening Quantity':100   , 'Closing Quantity': 100   ,'Sale Price': 100, 'Purchase Price':80},
            556690:{'Product name' :'Crispello','Brand Name' :'Cadbury', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 20, 'Purchase Price':15},
            556691:{'Product name' :'BarOne','Brand Name' :'Nestle', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 30, 'Purchase Price':20},
            556692:{'Product name' :'Nutties','Brand Name' :'Nutties', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 40, 'Purchase Price':35},
            556693:{'Product name' :'Alpenliebe','Brand Name' :'Perfetti Van Melle', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 2, 'Purchase Price':1},
            556694:{'Product name' :'Creamfills','Brand Name' :'Perfetti Van Melle', 'Opening Quantity':100, 'Closing Quantity': 100   ,'Sale Price': 10, 'Purchase Price':8},
            556695:{'Product name' :'Candyman','Brand Name' :'ITC Foods', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 10, 'Purchase Price':8},
            556696:{'Product name' :'Pulse','Brand Name' :'DS Group', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 2, 'Purchase Price':1},
            556697:{'Product name' :'Nestle','Brand Name' :'Nestle', 'Opening Quantity':100  , 'Closing Quantity': 100   ,'Sale Price': 10, 'Purchase Price':8},
            556698:{'Product name' :'Kismi','Brand Name' :'Parle', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 2, 'Purchase Price':1},
            556699:{'Product name' :'Mango Bite','Brand Name' :'Parle', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 2, 'Purchase Price':1},
            556700:{'Product name' :'Coffy Bite','Brand Name' :'Lotte', 'Opening Quantity':100 , 'Closing Quantity': 100   ,'Sale Price': 2, 'Purchase Price':1}

            }

# %%
Customer_record = {'XXXX' :{'Chocolates': 'Dairy Milk, Kitkat,Five star,Snikers,Eclairs,Perk,Dark Fantasy,bournville,Munch,Melody,Milkybar,Bounty,Ferrero Rocher, Toblerone,Mars, Gems,Temptation,Safari,Galaxy,Crispello,BarOne,Nutties,Alpenliebe,Creamfills,Candyman,Pulse,Nestle,Kismi,Mango Bite,Coffy Bite' },
                   998861: {'Name': 'Vaishnavi Salunkhe', 'Total purchase till now in Rs': 'Rs.2000', 'No. of purchases till now':'10','Most prefered brands':'Cadbury,Mars,Nestle Global'},
                   998862: {'Name': 'Nimisha Patil', 'Total purchase till now in Rs': 'Rs.2000', 'No. of purchases till now':'10','Most prefered brands':'Cadbury,Mars'},
                   998863: {'Name': 'Vaibhav Salunkhe', 'Total purchase till now in Rs': 'Rs.5000', 'No. of purchases till now':'35','Most prefered brands':'Cadbury,Nestle Global'},
                   998864: {'Name': 'Siddhi Patil', 'Total purchase till now in Rs': 'Rs.6000', 'No. of purchases till now':'49','Most prefered brands':'Cadbury,Sunfeast,Nestle Global'},
                   998865: {'Name': 'Roy Shah', 'Total purchase till now in Rs': 'Rs.4000', 'No. of purchases till now':'20','Most prefered brands':'Sunfeast,Mars,Nestle Global'},
                   998866: {'Name': 'Robbin Dsouza', 'Total purchase till now in Rs': 'Rs.2000', 'No. of purchases till now':'30','Most prefered brands':'Cadbury,Mars'},
                   998867: {'Name': 'David Dias', 'Total purchase till now in Rs': 'Rs.10000', 'No. of purchases till now':'55','Most prefered brands':'Sunfeast'},
                   998868: {'Name': 'Ram Shah', 'Total purchase till now in Rs': 'Rs.6000', 'No. of purchases till now':'25','Most prefered brands':'Cadbury,Sunfeast'},
                   998869: {'Name': 'Siya Shah', 'Total purchase till now in Rs': 'Rs.6000', 'No. of purchases till now':'27','Most prefered brands':'Nestle,Sunfeast'},
                   998870: {'Name': 'Arvind', 'Total purchase till now in Rs': 'Rs.3000', 'No. of purchases till now':'29','Most prefered brands':'Ferrero Rocher,Sunfeast'},
                   998871: {'Name': 'Leela', 'Total purchase till now in Rs': 'Rs.9000', 'No. of purchases till now':'40','Most prefered brands':'Cadbury,Sunfeast'},
                   998872: {'Name': 'Aditi', 'Total purchase till now in Rs': 'Rs.4000', 'No. of purchases till now':'30','Most prefered brands':'Parle,Ferrero Rocher,Sunfeast'},
                   998873: {'Name': 'Kiya', 'Total purchase till now in Rs': 'Rs.5000', 'No. of purchases till now':'25','Most prefered brands':'Ferrero Rocher,Cadbury,Sunfeast'},
                   998874: {'Name': 'Riya', 'Total purchase till now in Rs': 'Rs.6000', 'No. of purchases till now':'12','Most prefered brands':'Cadbury,Sunfeast'},
                   998875: {'Name': 'Ravi', 'Total purchase till now in Rs': 'Rs.9000', 'No. of purchases till now':'22','Most prefered brands':'Cadbury,Ferrero Rocher'},
                   998876: {'Name': 'Krish', 'Total purchase till now in Rs': 'Rs.3000', 'No. of purchases till now':'6','Most prefered brands':'Ferrero Rocher,Sunfeast'},
                   998877: {'Name': 'Rohan', 'Total purchase till now in Rs': 'Rs.2000', 'No. of purchases till now':'33','Most prefered brands':'DS Group ,Sunfeast'},
                   998878: {'Name': 'Kanha', 'Total purchase till now in Rs': 'Rs.9000', 'No. of purchases till now':'28','Most prefered brands':'Cadbury,ITC Foods'},
                   998879: {'Name': 'Rubbina', 'Total purchase till now in Rs': 'Rs.6000', 'No. of purchases till now':'34','Most prefered brands':'ITC Foods,Sunfeast'},
                   998880: {'Name': 'Sujan', 'Total purchase till now in Rs': 'Rs.5000', 'No. of purchases till now':'35','Most prefered brands':'Gandour,Cadbury,Sunfeast'},
                   998881: {'Name': 'Sarah', 'Total purchase till now in Rs': 'Rs.8000', 'No. of purchases till now':'45','Most prefered brands':'Cadbury,Gandour'},
                   998882: {'Name': 'Dhruvi', 'Total purchase till now in Rs': 'Rs.7000', 'No. of purchases till now':'40','Most prefered brands':'Cadbury,Procter & Gamble'},
                   998883: {'Name': 'Shruti', 'Total purchase till now in Rs': 'Rs.7000', 'No. of purchases till now':'35','Most prefered brands':'Cadbury,Sunfeast'},
                   998884: {'Name': 'Meghna', 'Total purchase till now in Rs': 'Rs.9000', 'No. of purchases till now':'55','Most prefered brands':'Parle,Sunfeast'},
                   998885: {'Name': 'Kalpesh', 'Total purchase till now in Rs': 'Rs.4000', 'No. of purchases till now':'15','Most prefered brands':'Mars,Sunfeast'},
                   998886: {'Name': 'Bala', 'Total purchase till now in Rs': 'Rs.5000', 'No. of purchases till now':'25','Most prefered brands':'Cadbury,Mars,Parle'},
                   998887: {'Name': 'Smit', 'Total purchase till now in Rs': 'Rs.6000', 'No. of purchases till now':'35','Most prefered brands':'Parle,Sunfeast'},
                   998888: {'Name': 'Upasana', 'Total purchase till now in Rs': 'Rs.7000', 'No. of purchases till now':'45','Most prefered brands':'Cadbury,Parle'},
                   998889: {'Name': 'Muthulaxmi', 'Total purchase till now in Rs': 'Rs.8000', 'No. of purchases till now':'45','Most prefered brands':'Cadbury,Sunfeast,Parle'},
                   998890: {'Name': 'Archana', 'Total purchase till now in Rs': 'Rs.9000', 'No. of purchases till now':'55','Most prefered brands':'Cadbury,Sunfeast,Mars'},
                   
                   }

# %%
js = json.dumps(Customer_record)
jst = json.dumps(record)

# %%
js
jst
# Out:
# '{"556671": {"Product name": "Dairy Milk", "Brand Name": "Cadbury", "Opening Quantity": 100, "Closing Quantity": 100, "Sale Price": 100, "Purchase Price": 80}, "556672": {"Product name": "Kitkat", "Brand Name": "Nestle global", "Opening Quantity": 100, "Closing Quantity": 100, "Sale Price": 40, "Purchase Price": 20}, "556673": {"Product name": "Five star", "Brand Name": "Cadbury", "Opening Quantity": 100, "Closing Quantity": 100, "Sale Price": 10, "Purchase Price": 5}, "556674": {"Product name": "Eclairs", "Brand Name": "Cadbury", "Opening Quantity": 100, "Closing Quantity": 100, "Sale Price": 2, "Purchase Price": 1}, "556675": {"Product name": "Dark Fantasy", "Brand Name": "SunFeast", "Opening Quantity": 100, "Closing Quantity": 100, "Sale Price": 50, "Purchase Price": 40}, "556676": {"Product name": "Perk", "Brand Name": "Cadbury", "Opening Quantity": 100, "Closing Quantity": 100, "Sale Price": 20, "Purchase Price": 15}, "556677": {"Product name": "Bournville", "Brand Name": "Cadbu
# ...

# %%
yes_no = input('Do you have a Customer_ID: ')
if(yes_no == 'no'):
  count=998869
  print('Here is your Customer_ID: ',996701 )
  count = count +1
if(yes_no == 'yes'):
  Customer_ID = input("Enter you Customer_ID ")
  if(Customer_ID == '998861' ):
    print('Hello, ',Customer_record[998861]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998861]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998862' ):
    print('Hello, ',Customer_record[998862]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998862]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998863' ):
    print('Hello, ',Customer_record[998863]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998863]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998864' ):
    print('Hello, ',Customer_record[998864]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998864]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998865' ):
    print('Hello, ',Customer_record[998865]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998865]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998866' ):
    print('Hello, ',Customer_record[998866]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998866]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998867' ):
    print('Hello, ',Customer_record[998867]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998867]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  
  elif(Customer_ID == '998868' ):
    print('Hello, ',Customer_record[998868]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998868]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998869' ):
    print('Hello, ',Customer_record[998869]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998869]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998870' ):
    print('Hello, ',Customer_record[998870]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998870]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998871' ):
    print('Hello, ',Customer_record[998871]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998871]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998872' ):
    print('Hello, ',Customer_record[998872]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998872]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998873' ):
    print('Hello, ',Customer_record[998873]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998873]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998874' ):
    print('Hello, ',Customer_record[998874]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998874]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998875' ):
    print('Hello, ',Customer_record[998875]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998875]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998876' ):
    print('Hello, ',Customer_record[998876]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998876]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998877' ):
    print('Hello, ',Customer_record[998877]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998877]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998878' ):
    print('Hello, ',Customer_record[998878]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998878]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998879' ):
    print('Hello, ',Customer_record[998879]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998879]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998880' ):
    print('Hello, ',Customer_record[998880]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998880]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998881' ):
    print('Hello, ',Customer_record[998881]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998881]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
    
  elif(Customer_ID == '998882' ):
    print('Hello, ',Customer_record[998882]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998882]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
 
  elif(Customer_ID == '998883' ):
    print('Hello, ',Customer_record[998883]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998883]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998884' ):
    print('Hello, ',Customer_record[998884]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998884]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998885' ):
    print('Hello, ',Customer_record[998885]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998885]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
    
  elif(Customer_ID == '998886' ):
    print('Hello, ',Customer_record[998886]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998886]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998887' ):
    print('Hello, ',Customer_record[998887]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998887]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998888' ):
    print('Hello, ',Customer_record[998888]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998888]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])

  elif(Customer_ID == '998889' ):
    print('Hello, ',Customer_record[998889]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998889]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  elif(Customer_ID == '998890' ):
    print('Hello, ',Customer_record[998890]['Name'],'Nice to see you again, How can i help you??? :)' )
    print('Here are your most preffered brands',Customer_record[998890]['Most prefered brands'])
    print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
  
  
  else:
    print('*****Invalid Customer_ID******')
# Out:
# Do you have a Customer_ID: no
# Here is your Customer_ID:  996701

# %%
print('Availble Chocolates are ',Customer_record['XXXX']['Chocolates'])
Purchased_Chocolates1 = "dairy milk"
Purchased_Chocolates2 = "Kitkat"
Purchased_Chocolates3 = 'Five Star'
Purchased_Chocolates4 = "Eclairs"
Purchased_Chocolates5 = "Dark Fantasy"
Purchased_Chocolates6 = "Perk"
Purchased_Chocolates7 = "Bournville"
Purchased_Chocolates8 = "Dark Chocolate"
No_of_DairyMilk = 3 #@param {type:"slider", min:0, max:10, step:1}

No_of_kitkat = 4 #@param {type:"slider", min:0, max:10, step:1}

No_of_FiveStars = 4 #@param {type:"slider", min:0, max:10, step:1}

No_of_eclairs = 4 #@param {type:"slider", min:0, max:10, step:1}

No_of_dark_fantacy = 3 #@param {type:"slider", min:0, max:10, step:1}

No_of_perk = 5 #@param {type:"slider", min:0, max:10, step:1}

No_of_Bournville = 4 #@param {type:"slider", min:0, max:10, step:1}

No_of_dark_chocolate = 3 #@param {type:"slider", min:0, max:10, step:1}
No_of_Munch = 2 #@param {type:"slider", min:0, max:10, step:1}
No_of_Milkybar = 6 #@param {type:"slider", min:0, max:10, step:1}
No_of_Melody = 1 #@param {type:"slider", min:0, max:10, step:1}
No_of_Bounty = 2 #@param {type:"slider", min:0, max:10, step:1}
No_of_Ferrero_Rocher = 2 #@param {type:"slider", min:0, max:10, step:1}
No_of_Toblerone = 1 #@param {type:"slider", min:0, max:10, step:1}
No_of_Mars = 5 #@param {type:"slider", min:0, max:10, step:1}
No_of_Gems = 1 #@param {type:"slider", min:0, max:10, step:1}
No_of_Temptation = 2 #@param {type:"slider", min:0, max:10, step:1}
No_of_Safari = 5 #@param {type:"slider", min:0, max:10, step:1}
No_of_Galaxy = 5 #@param {type:"slider", min:0, max:10, step:1}
No_of_Crispello = 6 #@param {type:"slider", min:0, max:10, step:1}
No_of_BarOne = 5 #@param {type:"slider", min:0, max:10, step:1}
No_of_Nutties = 8 #@param {type:"slider", min:0, max:10, step:1}
No_of_Alpenliebe = 3 #@param {type:"slider", min:0, max:10, step:1}
No_of_Creamfills = 10 #@param {type:"slider", min:0, max:10, step:1}
No_of_Candyman = 2 #@param {type:"slider", min:0, max:10, step:1}
No_of_Pulse = 5 #@param {type:"slider", min:0, max:10, step:1}
No_of_Nestle = 6 #@param {type:"slider", min:0, max:10, step:1}
No_of_Kismi = 3 #@param {type:"slider", min:0, max:10, step:1}
No_of_MangoBites = 8 #@param {type:"slider", min:0, max:10, step:1}
No_of_CoffyBites = 5 #@param {type:"slider", min:0, max:10, step:1}
# Out:
# Availble Chocolates are  Dairy Milk, Kitkat,Five star,Snikers,Eclairs,Perk,Dark Fantasy,bournville,Munch,Melody,Milkybar,Bounty,Ferrero Rocher, Toblerone,Mars, Gems,Temptation,Safari,Galaxy,Crispello,BarOne,Nutties,Alpenliebe,Creamfills,Candyman,Pulse,Nestle,Kismi,Mango Bite,Coffy Bite

# %%
Price1 = 0
Price2 = 0
Price3 = 0
Price4 = 0
Price5 = 0
Price6 = 0
Price7 = 0
Price8 = 0
Price9 = 0
Price10 = 0
Price11 = 0
Price12 = 0
Price13 = 0
Price14 = 0
Price15 = 0
Price16 = 0
Price17 = 0
Price18 = 0
Price19 = 0
Price20 = 0
Price21 = 0
Price22 = 0
Price23 = 0
Price24 = 0
Price25 = 0
Price26 = 0
Price27 = 0
Price28 = 0
Price29 = 0
Price30 = 0

if(No_of_DairyMilk != 0):
  Price1 = record[556671]['Sale Price'] * No_of_DairyMilk
  print('Dairy Milk = ', Price1)

if(No_of_kitkat != 0):
  Price2 = record[556672]['Sale Price'] * No_of_kitkat
  print('Kitkat = ', Price2)

if(No_of_FiveStars != 0):
  Price3 = record[556673]['Sale Price'] * No_of_FiveStars
  print('Five Stars = ', Price3)

if(No_of_eclairs != 0):
  Price4 = record[556674]['Sale Price'] * No_of_eclairs
  print('Eclairs = ', Price4)

if(No_of_dark_fantacy != 0):
  Price5 = record[556675]['Sale Price'] * No_of_dark_fantacy
  print('Dark Fantacy = ', Price5)

if(No_of_perk != 0):
  Price6 = record[556676]['Sale Price'] * No_of_perk
  print('Perk = ', Price6)

if(No_of_Bournville != 0):
  Price7 = record[556677]['Sale Price'] * No_of_Bournville
  print('Bournville = ', Price7)

if(No_of_dark_chocolate != 0):
  Price8 = record[556678]['Sale Price'] * No_of_dark_chocolate
  print('Dark Chocolate = ', Price8)

if(No_of_Munch != 0):
  Price9 = record[556679]['Sale Price'] * No_of_Munch
  print('Munch = ', Price9)

if(No_of_Milkybar != 0):
  Price10 = record[556680]['Sale Price'] * No_of_Milkybar
  print('Milkybar = ', Price10)

if(No_of_Melody != 0):
  Price11 = record[556681]['Sale Price'] * No_of_Melody
  print('Melody = ', Price11)

if(No_of_Bounty != 0):
  Price12 = record[556682]['Sale Price'] * No_of_Bounty
  print('Bounty = ', Price12)

if(No_of_Ferrero_Rocher != 0):
  Price13 = record[556683]['Sale Price'] * No_of_Ferrero_Rocher
  print('Ferrero Rocher = ', Price13)

if(No_of_Toblerone != 0):
  Price14 = record[556684]['Sale Price'] * No_of_Toblerone
  print('Toblerone = ', Price14)

if(No_of_Mars != 0):
  Price15 = record[556685]['Sale Price'] * No_of_Mars
  print('Melody = ', Price15)

if(No_of_Gems != 0):
  Price16 = record[556686]['Sale Price'] * No_of_Gems
  print('Gems = ', Price16)

if(No_of_Temptation != 0):
  Price17 = record[556687]['Sale Price'] * No_of_Temptation
  print('Temptation = ', Price17)

if(No_of_Safari != 0):
  Price18 = record[556688]['Sale Price'] * No_of_Safari
  print('Safari = ', Price18)

if(No_of_Galaxy != 0):
  Price19 = record[556689]['Sale Price'] * No_of_Galaxy
  print('Galaxy = ', Price19)

if(No_of_Crispello != 0):
  Price20 = record[556690]['Sale Price'] * No_of_Crispello
  print('Crispello = ', Price20)

if(No_of_BarOne != 0):
  Price21 = record[556691]['Sale Price'] * No_of_BarOne
  print('BarOne = ', Price21)

if(No_of_Nutties != 0):
  Price22 = record[556692]['Sale Price'] * No_of_Nutties
  print('Nutties = ', Price22)

if(No_of_Alpenliebe != 0):
  Price23 = record[556693]['Sale Price'] * No_of_Alpenliebe
  print('Alpenliebe = ', Price23)

if(No_of_Creamfills != 0):
  Price24 = record[556694]['Sale Price'] * No_of_Creamfills
  print('Creamfills = ', Price24)

if(No_of_Candyman != 0):
  Price25 = record[556695]['Sale Price'] * No_of_Candyman
  print('Candyman = ', Price25)

if(No_of_Pulse != 0):
  Price26 = record[556696]['Sale Price'] * No_of_Pulse
  print('Pulse = ', Price26)

if(No_of_Nestle != 0):
  Price27 = record[556697]['Sale Price'] * No_of_Nestle
  print('Nestle = ', Price27)

if(No_of_Kismi != 0):
  Price28 = record[556698]['Sale Price'] * No_of_Kismi
  print('Kismi = ', Price28)

if(No_of_MangoBites != 0):
  Price29 = record[556699]['Sale Price'] * No_of_MangoBites
  print('Mango Bite = ', Price29)

if(No_of_CoffyBites != 0):
  Price30 = record[556700]['Sale Price'] * No_of_CoffyBites
  print('Coffy Bite = ', Price30)

print('Total Bill is  ',Price1 +  Price2 + Price3 +  Price4 + Price5 +  Price6 + Price7 +  Price8 + Price9 + Price10 + Price11 + Price12 + Price13 + Price14 + Price15 + Price16 + Price17 + Price18 + Price19 + Price20 + Price21 + Price22 + Price23 + Price24 + Price25 + Price26 + Price27 + Price28 + Price29 + Price30)
Total_Price = Price1 +  Price2 + Price3 +  Price4 + Price5 +  Price6 + Price7 +  Price8 + Price9 + Price10 + Price11 + Price12 + Price13 + Price14 + Price15 + Price16 + Price17 + Price18 + Price19 + Price20 + Price21 + Price22 + Price23 + Price24 + Price25 + Price26 + Price27 + Price28 + Price29 + Price30
if(Total_Price >= 1000):
 discount = (5/100)*Total_Price
 print("Hurray, You have got Special Discount", discount )
 print("Now your Total bill is ",Total_Price-discount )
# Out:
# Dairy Milk =  300
# Kitkat =  160
# Five Stars =  40
# Eclairs =  8
# Dark Fantacy =  150
# Perk =  100
# Bournville =  400
# Dark Chocolate =  300
# Munch =  20
# Milkybar =  60
# Melody =  50
# Bounty =  200
# Ferrero Rocher =  200
# Toblerone =  100
# Melody =  250
# Gems =  10
# Temptation =  200
# Safari =  400
# Galaxy =  500
# Crispello =  120
# BarOne =  150
# Nutties =  320
# Alpenliebe =  6
# Creamfills =  100
# Candyman =  20
# Pulse =  10
# Nestle =  60
# Kismi =  6
# Mango Bite =  16
# Coffy Bite =  10
# Total Bill is   4266
# Hurray, You have got Special Discount 213.3
# Now your Total bill is  4052.7

# %%
fd = open("Customer_record.json" , 'w')
fd.write(js)
fd.close()

# %%
fd = open("Customer_record.json" , 'r')
txt = fd.read()
fd.close()
